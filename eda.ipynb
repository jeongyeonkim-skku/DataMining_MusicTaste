# %%
import pandas as pd

df = pd.read_csv("../data/processed/final_data.csv")
df.head()

# %%
df.describe()

# %%
df.groupby("age_group")["release_year"].mean().plot(kind="bar")

# %%
df["release_year"].hist()
